# %% [markdown]
# # conditional statements in python
# 1. python have 4 types of conditional statements
# 2. `if` statement
# 3. `elif` statement
# 4. `nested` statement
#
# ```python sytax - if
# if(conditions):# if conditions is True then execute or run statements inside if block
#    statement1
#    statement2...
# ```
#
# ```python - if, else
# if (condition):
#     statement1
#     statement2...
# else:
#     statement1
#     statement2..
# ```
#
# ```python - if,elif,else
# if (condition):
#    statements1..n
# elif(conditions2):
#     statements1..n
# elif (conditions3):
#     statements..n
#
# else:
#     statements1..n
# ```

# %%
# write a program to find the given number is od?
number = int(input("please enter number here:"))
if (number%2 == 1):
    print(number,"is odd number")
# Out:
# please enter number here: 120

# %%
#write a program to find the given number is even or odd?
num = int(input("please enter number here:"))
if (num%2 == 0):
    print(num,"is odd integer")

# %%
print(n,"is zero")

# %%
"""
write a program to find the grades based on marks 
1. if marks in between 80-100 - grade is A

# %%
n1=int(input("enter first number here:"))
n2=int(input("enter second number here:"))
n3=int(input("enter third number here:"))

if n1>n2 and n1>n3:
   print(n1, "is the largest number")
elif n2>n1 and n2>n3:
     print(n2, "is the largest number")
elif n3>n2 and n3>n1:
    print(n3, "is the largest number")
# Out:
# enter first number here: 6626
# enter second number here: 4587

# %%
# write a program to validate Login credentials using conditionals statements?
 username=str(

# %%
"""
write a program to find the even number with number of digits 
1. if number in between 1 to 9 then output is - 1 digit even number 
2. if number in between 10 to 99 then output is
